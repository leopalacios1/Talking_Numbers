# %%
# LOAD EXTRACTION RESULT


import pandas as pd

# IMPORT SECTION ___________________________________________________________

# LOAD DATASETS IDS FROM CSV FILE
IDs_df = pd.read_csv("Data/Dataset_Info.csv",";")

# LOAD DATASETS INFO
INFO       = pd.read_csv("Data/Dataset_Info.csv",";")

for index, row in INFO.iterrows():
    play = row['PLAYLIST']
    playDf = pd.read_csv("Data/Datasets/Dataset" + str(play) + ".csv")    
    COLLECTION[index] = playDf
# ___________________________________________________________________________

# MAKE SIMPLE 0/1 PREFERENCE UNIONS

likedSongsUNION = COLLECTION[1]

for key in COLLECTION.keys():
    if key > 0:
        print(key)
        print(COLLECTION[key].shape[0])
        likedSongsUNION = likedSongsUNION.append(COLLECTION[key])

#likedSongsUNION

# %%
import pandas as pd

# Data Visualization

L  = pd.DataFrame()
DL = pd.read_csv("Data/Datasets\Dataset0.csv",",")

for play in range(1,20):
    playDf = pd.read_csv("Data/Datasets/Dataset" + str(play) + ".csv") 
    L=pd.concat([G,playDf])
    
# Select 
    
L  =  L[['release_date','popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo']]
L['Classification'] = 'Like'

DL = DL[['release_date','popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo']]
L['Classification'] = 'Dislike'


# Remove observations with NaN in a given feature
L.dropna()
DL.dropna()
    
# Change date info
for index, row in L.iterrows():
        Date    = row['release_date']
        newDate = Date[0:4]
        L.at[index,'release_date'] = newDate
        
for index, row in DL.iterrows():
        Date    = row['release_date']
        newDate = Date[0:4]
        DL.at[index,'release_date'] = newDate        

# Using 'Address' as the column name
# and equating it to the list
df['Classification'] = 1
df
# Out:
#     release_date  popularity  acousticness  danceability  energy  \
# 0           2018          54       0.00596         0.633   0.919
# 1           1964          65       0.41200         0.652   0.583
# 2           2018          69       0.29100         0.863   0.533
# 3           1984          30       0.59500         0.606   0.752
# 4           1980          35       0.31200         0.731   0.709
# ..           ...         ...           ...           ...     ...
# 428         1970          63       0.01500         0.619   0.637
# 429         1967          58       0.69500         0.510   0.310
# 430         2015           0       0.22900         0.539   0.383
# 431         1980          55       0.09640         0.510   0.595
# 432         2016          50       0.52900         0.624   0.650
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# 0            0.273000    0.4300    -6.208       0.0343  147.970
# 1            0.000000    0.1190    -7.811       0.0380  138.134
# 2            0.001260    0.0794    -7.986       0.0484  102.025
# 3            0.000035    0.0465    -7.360       0.0751  192.624
# 4            0.226000    0.1190   -13.613       0.0640  112.426
# ..                ...       ...       ...          ...      ...
# 428          0.000000    0.3740    -7.369       0.0286  105.205
# 429          0.000000    0.1280   -13.647       0.0291   90.074
# 430          0.261000    0.3610   -12.634       0.0297  113.950
# 431          0.018600    0.3380   -11.023       0.0383  131.762
# 432          0.074800    0.3340    -5.993       0.0277  106.990
#
#      Classification
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 428               1
# 429               1
# 430               1
# 431               1
# 432               1
#
# [433 rows x 11 columns]

# %%
        
# Seaborn visualization library
import seaborn as sns

# Create the default pairplot
sns.pairplot(df)
