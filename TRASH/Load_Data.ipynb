# %%
#!pip install spotipy
#!pip install pandas

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time 

client_id = '9eb4c6ef069845e4bde31c6581daac26'
client_secret  = '9995ec38d7294435acfb7c8fe81b99ec'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

# 4cd2uvFZqm4jhG5YMsYrfD   - Poolside
# 4DKoYXYGhrLTMOqbbmg2MF   - Top 16-20
# 6Py24jkNM9zRUJjVPQtPQA   - A time for us
# 37i9dQZF1DX3Gj7nguS95W   - Is it new wave
# 3UfIv8pw5qYmwy0TGyraRB   - Jazz Queens
# 37i9dQZF1DWVyizF9BJ61m   - Afro Psychedelia



# 7Gos6Zpwag9zNHl6fGPFki   - Forgetten Discoveries
# 37i9dQZF1DXe8E8oqpmTDI   - This is Mac Demarco
# 37i9dQZF1DWZAkrucRF6Gq   - This is Daft Punk
# 37i9dQZF1DWXMmak2OV7PN   - This is Alt-J
# 37i9dQZF1DZ06evO3fWxA4   - This is Los Amigos Invisibles
# 1aWzgi9FMNLzlVda2hsPeo   - HVibes
#
#
#
#
#
#
#
# PlayList = [ [ "7Gos6Zpwag9zNHl6fGPFki"],[]

Playlists = {'7Gos6Zpwag9zNHl6fGPFki': 'Forgetten_Discoveries', \
             '37i9dQZF1DXe8E8oqpmTDI': 'Mac_demarco', \
             '37i9dQZF1DWZAkrucRF6Gq': 'Daft_punk', \
             '37i9dQZF1DWXMmak2OV7PN': 'alt_j', \
             '7Gos6Zpwag9zNHl6fGPFki': 'amigos_invisibles', \
             '1aWzgi9FMNLzlVda2hsPeo': 'HVibes', \
             '2LYsJ0gtkQ89bDDMqZ0UEa': 'Psych', \
             '49CvOK9Ye9gw0u4GTPvqAs': 'The_Dead', \
             '7gx2w3tJUjnvxIxQwtH7yU': 'Funky', \
             '3eNsdqbbLFIh0df8pMK2UX': 'Reggae'}
             
  
ids = getTrackIDs('1124570809', '37i9dQZF1DWVyizF9BJ61m')

print(len(ids))
print(ids)

def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])
df.to_csv("Afro_Psychedelia.csv", sep = ',')

df.shape
df.head()
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-67be34a62913> in <module>
#       4 import spotipy
#       5 from spotipy.oauth2 import SpotifyClientCredentials
# ----> 6 import pandas as pd
#       7 import time
#       8
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.shape
# Out:
# (50, 16)

# %%
df.head()
# Out:
#                                     name  \
# 0  Never (Lagos Never Gonna Be the Same)
# 1                         Free My People
# 2                      Akula Owu Onyeara
# 3                             Born Black
# 4                        Khala My Friend
#
#                                                album           artist  \
# 0                                            Rejoice       Tony Allen
# 1  Soul Jazz Records Presents Nigeria Soul Fever:...  Various Artists
# 2  Dancing Time, the Best of Eastern Nigeria's Af...      The Funkees
# 3  Welcome To Zamrock! How Zambia's Liberation Le...  Various Artists
# 4  Welcome To Zamrock! How Zambia's Liberation Le...  Various Artists
#
#   release_date  length  popularity  danceability  acousticness  danceability  \
# 0   2020-03-20  233680          47         0.766         0.178         0.766
# 1         1978  292680           0         0.601         0.136         0.601
# ...

# %%
import seaborn as sns


df2 = df.select_dtypes(include='number') # keep only numeric variables 
df2 = df2.dropna() 
df2.head()

df3 = df2[['popularity', 'danceability', 'acousticness', 'energy' ,'instrumentalness' , 'liveness' , 'loudness','speechiness','tempo']]
df3.head()
df3.columns
# Out:
# Index(['popularity', 'danceability', 'danceability', 'acousticness', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo'],
#       dtype='object')

# %%
g= sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-605d6a2028fd> in <module>
# ----> 1 g= sns.pairplot(df)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
# -> 1991                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    1992
# ...
