# %%
# LOAD EXTRACTION RESULT


import pandas as pd

# IMPORT SECTION ___________________________________________________________

# LOAD DATASETS IDS FROM CSV FILE
IDs_df = pd.read_csv("Data/Dataset_Info.csv",";")
IDs_df

# LOAD DATASETS INFO
INFO = pd.read_csv("Data/Dataset_Info.csv",";")
COLLECTION = {}
for index, row in INFO.iterrows():
    play = row['PLAYLIST']
    playDf = pd.read_csv("Data/Datasets/Dataset" + str(play) + ".csv")    
    COLLECTION[index] = playDf
# ___________________________________________________________________________

# MAKE SIMPLE 0/1 PREFERENCE UNIONS

likedSongsUNION = COLLECTION[1]

for key in COLLECTION.keys():
    if key > 0:
        print(COLLECTION[key].shape[0])
        likedSongsUNION = likedSongsUNION.append(COLLECTION[key])

likedSongsUNION
# Out:
# 100
# 100
# 50
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 0
# 97
# 0
# 100
# 100
# 100
# 0
# 0
#    Unnamed: 0                                               name  \
# 0           0                                        Va pensiero
# 1           1  Zadok the Priest (Coronation Anthem No. 1, HWV...
# 2           2                  Turandot / Act 3: "Nessun dorma!"
# 3           3       La Traviata / Act 1: Libiamo ne'lieti calici
# 4           4             Rigoletto / Act 3: "La donna è mobile"
# ..        ...                                                ...
# 95         95                                           No Other
# 96         96                       Sandra (When The Earth Dies)
# 97         97                                   Sons & Daughters
# 98         98                                             Nantes
# 99         99                                      Find Yourself
#
#                                                 album             artist  \
# 0          Je n'aime pas Verdi, mais ça j'aime bien !     Giuseppe Verdi
# 1   Carmina Burana - The Greatest Classical Choir ...    Various Artists
# 2                      Puccini: Turandot - Highlights    Giacomo Puccini
# 3                                  Verdi: La Traviata     Giuseppe Verdi
# 4                                   Pavarotti Forever  Luciano Pavarotti
# ..                                                ...                ...
# 95                                           No Other         Gene Clark
# 96                    For the Recently Found Innocent        White Fence
# 97                                     The Crane Wife   The Decemberists
# 98                                The Flying Club Cup             Beirut
# 99                                        Hypnophobia      Jacco Gardner
#
#    release_date  length popularity  danceability  acousticness  \
# 0    2019-05-17  290613         35         0.240        0.9760
# 1    2014-10-17  318000          0         0.291        0.8770
# 2    1973-01-01  177333         63         0.212        0.9630
# 3    1977-01-01  175506         56         0.424        0.9620
# 4    1997-01-01  142173         59         0.369        0.9590
# ..          ...     ...        ...           ...           ...
# 95   1974-09-01  308533         46         0.467        0.4200
# 96   2014-07-22  146280         34         0.758        0.2020
# 97   2006-10-03  313600         52         0.331        0.2240
# 98   2007-10-08  230200         62         0.437        0.7820
# 99   2015-05-04  214175         32         0.577        0.0162
#
#     danceability.1  energy  instrumentalness  liveness  loudness  speechiness  \
# 0            0.240  0.1570          0.924000    0.1080   -17.034       0.0382
# 1            0.291  0.0939          0.779000    0.0799   -21.057       0.0342
# 2            0.212  0.3010          0.003300    0.1300   -12.505       0.0384
# 3            0.424  0.2140          0.000029    0.6810   -17.688       0.0763
# 4            0.369  0.2100          0.000045    0.0905   -13.552       0.0437
# ..             ...     ...               ...       ...       ...          ...
# 95           0.467  0.6170          0.724000    0.1370   -13.997       0.0404
# 96           0.758  0.4460          0.004720    0.1750   -10.971       0.1950
# 97           0.331  0.5590          0.000000    0.2970    -8.263       0.0316
# 98           0.437  0.5330          0.014200    0.1340    -9.552       0.0426
# 99           0.577  0.7400          0.660000    0.0996    -5.925       0.0282
#
#       tempo time_signature
# 0    68.828              4
# 1   102.084              4
# 2    84.025              4
# 3   113.211              4
# 4   131.714              3
# ..      ...            ...
# 95   96.878              4
# 96   84.484              4
# 97  115.117              4
# 98  131.155              4
# 99  150.078              4
#
# [1647 rows x 17 columns]
